# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input

# Define the autoencoder model architecture
input_dim = 1380  # Adjust this based on your actual input dimension
encoding_dim = 64  # Adjust this based on your actual encoding dimension

input_layer = Input(shape=(input_dim,))
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(encoding_dim, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)

# Load the trained autoencoder weights
autoencoder.load_weights("trained_autoencoder_model.h5")  # Replace with your actual weights file

# Create a function that uses the autoencoder for reconstruction
def reconstruct_data(input_data):
    """
    Reconstruct input data using the trained autoencoder.

    Parameters:
    input_data (numpy.ndarray): Input data of shape (n_samples, input_dim).

    Returns:
    numpy.ndarray: Reconstructed data of the same shape as input_data.
    """
    # Preprocess input_data if necessary (e.g., scaling)
    # input_data = preprocess(input_data)
    
    # Use the autoencoder for reconstruction
    reconstructed_data = autoencoder.predict(input_data)

    return reconstructed_data

# Example usage:
if __name__ == "__main__":
    # Load your data for testing
    test_data = np.random.rand(10, input_dim)  # Replace with your actual test data
    
    # Reconstruct the test data using the autoencoder
    reconstructed_test_data = reconstruct_data(test_data)
    
    # You can now use 'reconstructed_test_data' for further analysis or evaluation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10216\1050654709.py in <module>
#       8
#       9 input_layer = Input(shape=(input_dim,))
# ---> 10 encoded = Dense(128, activation='relu')(input_layer)
#      11 encoded = Dense(encoding_dim, activation='relu')(encoded)
#      12 decoded = Dense(128, activation='relu')(encoded)
#
# NameError: name 'Dense' is not defined
