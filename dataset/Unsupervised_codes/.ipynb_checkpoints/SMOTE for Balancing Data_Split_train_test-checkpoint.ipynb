# %%
# check version number
import imblearn
print(imblearn.__version__)
# Out:
# 0.11.0

# %%
# In this section, we will develop an intuition for the SMOTE by applying it to an imbalanced binary classification problem.
from collections import Counter
from sklearn.datasets import make_classification
from matplotlib import pyplot
import matplotlib.pyplot as plt
from numpy import where
import pandas as pd
import numpy as np
import os

# define dataset
#df = pd.read_csv("C:\\Users\\olufe\\projects\\Journal\\dataset\\HomeA_unsupervised_sim_combined_shuffled.csv")
#X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0,
#	n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# %%
# Option A
# Function to read data from the CSV file and split it into X and y
def read_data_from_csv(csv_file_path):
    data = pd.read_csv(csv_file_path)
    X = data.iloc[:, :-1]  # All columns except the last one are input features
    y = data.iloc[:, -1]   # The last column is the target variable
    return X, y

# Define the CSV file path
csv_file_path = r"C:\Users\olufe\projects\Journal\dataset\HomeA_unsupervised_sim_combined_data.csv"

# Read the data from the CSV file
X, y = read_data_from_csv(csv_file_path)

# If you want to generate the data using make_classification (not using CSV), uncomment the following line
# X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# Print some information about the data
print("X shape:", X.shape)
print("y shape:", y.shape)

# Now, you have X and y filled with the data from the CSV file or generated using make_classification.
# Out:
# X shape: (35330, 1380)
# y shape: (35330,)

# %%
# File path
csv_file_path = r"C:\Users\olufe\projects\Journal\dataset\HomeA_unsupervised_sim_combined_data.csv"

# Load the data from the CSV file
data = pd.read_csv(csv_file_path)

# Extract features (X) and target labels (y) from the loaded data
X = data.drop(columns=["Label"])  # Replace "target_column_name" with the actual column name for the target variable
y = data["Label"]  # Replace "target_column_name" with the actual column name for the target variable

# Print the extracted values of X and y
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (35330, 1380)
# y shape: (35330,)

# %%
# Option B
# File paths
#train_csv_file_path = r"C:\Users\olufe\projects\Journal\dataset\psa_journal_home_A_unsupervise_train.csv"
#test_csv_file_path = r"C:\Users\olufe\projects\Journal\dataset\psa_journal_home_A_sim_test.csv"

# Load the training data from the CSV file
#train_data = pd.read_csv(train_csv_file_path)

# Load the test data from the CSV file
#test_data = pd.read_csv(test_csv_file_path)

# Extract features (X) and target labels (y) from the training data
#X_train = train_data.drop(columns=["target_column_name"])  # Replace "target_column_name" with the actual column name for the target variable in the training data
#y_train = train_data["target_column_name"]  # Replace "target_column_name" with the actual column name for the target variable in the training data

# Extract features (X) and target labels (y) from the test data
#X_test = test_data.drop(columns=["target_column_name"])  # Replace "target_column_name" with the actual column name for the target variable in the test data
#y_test = test_data["target_column_name"]  # Replace "target_column_name" with the actual column name for the target variable in the test data

# If needed, convert the target labels to numerical values
# For example, if the target labels are strings like "Class A" and "Class B", you can map them to integers like 0 and 1.
# If the target labels are already numerical, you can skip this step.

# Now you can use the make_classification function to generate synthetic data if needed for both training and test datasets.
# If you just want to fill in the values of X and y from the CSV files, you can skip this step.
# For example, if you want to generate synthetic data with 10,000 samples, 2 features, and 99% of the data belonging to one class:
# X_train, y_train = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
# X_test, y_test = make_classification(n_samples=number_of_test_samples, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# Now you have filled in the values for X_train, y_train, X_test, and y_test from the CSV files.

# %%
# Option C

# Load data from the first CSV file
#train_csv_file_path = r"C:\Users\olufe\projects\Journal\dataset\psa_journal_home_A_unsupervise_train.csv"
#train_data = pd.read_csv(train_csv_file_path)

# Load data from the second CSV file
#test_csv_file_path = r"C:\Users\olufe\projects\Journal\dataset\psa_journal_home_A_sim_test.csv"
#test_data = pd.read_csv(test_csv_file_path)

# Combine the data from both files to create the full dataset
#data = pd.concat([train_data, test_data], axis=0, ignore_index=True)

# Extract features (X) and target labels (y) from the combined data
#X = data.drop(columns=["target_column_name"])  # Replace "target_column_name" with the actual column name for the target variable
#y = data["target_column_name"]  # Replace "target_column_name" with the actual column name for the target variable

# Generate synthetic data for the remaining samples using the make_classification function
#n_samples_remaining = 10000 - len(data)
#synthetic_X, synthetic_y = make_classification(n_samples=n_samples_remaining, n_features=2, n_redundant=0,
#                                               n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# Concatenate the synthetic data with the existing data to create the final X and y
#X = pd.concat([X, pd.DataFrame(synthetic_X)], axis=0, ignore_index=True)
#y = pd.concat([y, pd.Series(synthetic_y)], axis=0, ignore_index=True)

# Print the value of X and y
#print("X:")
#print(X)

#print("\ny:")
#print(y)

# %%
#df.info()

# %%
#df.describe

# %%
# summarize class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 35186, 1: 144})

# %%
# Plot scatter points for each label in y
unique_labels = y.unique()
for label in unique_labels:
    row_ix = y[y == label].index
    plt.scatter(X.loc[row_ix, X.columns[0]], X.loc[row_ix, X.columns[1]], label=str(label))
plt.legend()
plt.show()

# scatter plot of examples by class label
#for label, _ in counter.items():
#	row_ix = where(y == label)[0]
#	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
#pyplot.legend()
#pyplot.show()
