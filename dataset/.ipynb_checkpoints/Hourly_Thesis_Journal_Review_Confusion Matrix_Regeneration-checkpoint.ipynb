# %% [markdown]
# ## Home C_Confusion Matrix
#
# ### Regularized & Normalized
#
# ### XGBOOST - Home C_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# array = [[94545,0],
#          [0,86199]]
array = [[6939, 76],
         [563, 5737]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_sim'}, cmap=plt.cm.Reds) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - XGB-Home C_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\XGBr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6939, 76],
         [563, 5737]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home C_sim'}, cmap=plt.cm.Reds)

# Set title and labels
plt.title("Confusion Matrix - XGB-Home C_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\XGBn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### Random Forest - Home C_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix

array = [[6963, 52],
         [930, 5370]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_sim'}, cmap=plt.cm.Blues) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - RF-Home C_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\RFr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6963, 52],
         [930, 5370]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home C_sim'}, cmap=plt.cm.Blues)

# Set title and labels
plt.title("Confusion Matrix - RF-Home C_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\RFn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### Multilayer Perceptron (MLP) - Home C_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6638, 377],
         [709, 5591]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_sim'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - MLP-Home C_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\MLPr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6638, 377],
         [709, 5591]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home C_sim'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - MLP-Home C_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\MLPn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### XGBOOST_Home_C_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
# array = [[94545,0],
#          [0,86199]]
array = [[6939, 76],
         [563, 5737]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Reds) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - XGB-Home C_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\XGBr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6939, 76],
         [563, 5737]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Reds)

# Set title and labels
plt.title("Confusion Matrix - XGB-Home C_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\XGBn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### RF_Home_C_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6960, 55],
         [930, 5370]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Blues) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - RF-Home C_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\RFr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6960, 55],
         [930, 5370]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Blues)

# Set title and labels
plt.title("Confusion Matrix - RF-Home C_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\RFn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### MLP_Home_C_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6594, 421],
         [752, 5548]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - MLP-Home C_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\MLPr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6638, 377],
         [709, 5591]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - MLP-Home C_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\MLPn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ## Home B_Confusion Matrix
#
# ### Regularized & Normalized
#
# ### XGBOOST - Home B_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6985, 36],
         [464, 6172]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_sim'}, cmap=plt.cm.Reds) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - XGB-Home B_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\XGBr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6985, 36],
         [464, 6172]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home B_sim'}, cmap=plt.cm.Reds)

# Set title and labels
plt.title("Confusion Matrix - XGB-Home B_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\XGBn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### Random Forest - Home_B_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[7009, 12],
         [827, 5809]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_sim'}, cmap=plt.cm.Blues) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - RF-Home B_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\RFr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[7009, 12],
         [827, 5809]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home B_sim'}, cmap=plt.cm.Blues)

# Set title and labels
plt.title("Confusion Matrix - RF-Home B_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\RFn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### Multilayer Perceptron (MLP) - Home B_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6947, 74],
         [622, 6014]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_sim'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - MLP-Home B_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\MLPr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6947, 74],
         [622, 6014]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home B_sim'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - MLP-Home B_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\MLPn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### XGBOOST_Home_B_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6985, 36],
         [464, 6172]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Reds) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - XGB-Home B_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\XGBr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6985, 36],
         [464, 6172]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Reds)

# Set title and labels
plt.title("Confusion Matrix - XGB-Home B_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\XGBn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### RF_Home_B_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[7008, 13],
         [824, 5812]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Blues) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - RF-Home B_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\RFr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array =  [[7008,  13],
          [ 824, 5812]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Blues)

# Set title and labels
plt.title("Confusion Matrix - RF-Home B_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\RFn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### MLP_Home_B_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6838, 183],
         [539, 6097]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - MLP-Home B_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\MLPr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6838, 183],
         [539, 6097]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - MLP-Home B_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\MLPn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Home A_Confusion Matrix
#
# ### Regularized & Normalized
#
# ### XGBOOST - Home A_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6890, 90],
         [597, 6195]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Reds) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - XGB-Home A_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\XGBr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6890, 90],
         [597, 6195]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Reds)

# Set title and labels
plt.title("Confusion Matrix - XGB-Home A_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\XGBn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### Random Forest - Home_A_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6924, 56],
         [1072, 5720]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Blues) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - RF-Home A_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\RFr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6924, 56],
         [1072, 5720]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Blues)

# Set title and labels
plt.title("Confusion Matrix - RF-Home A_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\RFn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### Multilayer Perceptron (MLP) - Home A_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6655, 325],
         [727, 6065]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - MLP-Home A_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\MLPr_cm_sim.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6655, 325],
         [727, 6065]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - MLP-Home A_sim", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\MLPn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### XGBOOST_Home_A_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6890, 90],
         [597, 6175]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_real'}, cmap=plt.cm.Reds) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - XGB-Home A_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\XGBr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6890, 90],
         [597, 6175]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_real'}, cmap=plt.cm.Reds)

# Set title and labels
plt.title("Confusion Matrix - XGB-Home A_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\XGBn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### RF_Home_A_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6923, 57],
         [1073, 5719]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_real'}, cmap=plt.cm.Blues) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - RF-Home A_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\RFr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array =  [[6923,  57],
          [ 1073, 5719]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_real'}, cmap=plt.cm.Blues)

# Set title and labels
plt.title("Confusion Matrix - RF-Home A_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\RFn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### MLP_Home_A_real

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6649, 331],
         [715, 6077]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_real'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - MLP-Home A_real")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\MLPr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6649, 331],
         [715, 6077]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_real'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - MLP-Home A_real", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\MLPn_cm_real.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### SVM Confusion Matrix

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6718, 297],
         [988, 5312]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - SVM-Home A_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\SVMr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6718, 297],
         [988, 5312]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - SVM-Home A", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\SVMn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### LR Confusion Matrix - Home A_sim

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# Original confusion matrix
array = [[6243, 772],
         [1694, 4606]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Greens) # font size
# sn.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",annot_kws={"size": 12}, cmap=plt.cm.Blues) # font size
# sns.heatmap(cm_df, annot=True, fmt='0.2f', cmap=model_info['cmap'], linewidths=0.5, square=True, cbar_kws={'label': 'Home A'})
# plt.title("Confusion Matrix - DoS")
plt.title("Confusion Matrix - LR-Home A_sim")
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\LRr_cm_real.png', bbox_inches='tight')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[6243, 772],
         [1694, 4606]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]

# Set the plot size and font size
plt.rcParams.update({'font.size': 10})

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])

# Plot the heatmap
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, annot=True, fmt=".2f", annot_kws={"size": 10}, linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Greens)

# Set title and labels
plt.title("Confusion Matrix - SVM-Home A", fontsize=10, fontweight='bold')
plt.ylabel('True class', fontsize=10, fontweight='bold')
plt.xlabel('Predicted class', fontsize=10, fontweight='bold')

# Save the plot
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_A_up\SVMn_cm_sim.png', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### IF - Home C

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[8289, 471],
        [4023, 4737]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Greys) # font size
plt.title("Confusion Matrix - IF Home C_real", fontsize=10)
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\LUM_IF_real_r.png', bbox_inches='tight')

# Original confusion matrix
array = [[8289, 471],
         [4023, 4737]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]


plt.rcParams.update({'font.size': 10})
# df_cm = pd.DataFrame(array, range(2), range(2))

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])
# LABELS = ['Benign', 'DoS']
# LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home C_real'}, cmap=plt.cm.Greys) # font size
plt.title("Confusion Matrix - IF Home C_real", fontsize=10)
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_C_up\LUM_IF_real_n.png', bbox_inches='tight')

# %% [markdown]
# ### IF-Home B

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[8463, 297],
         [7822, 938]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home A_sim'}, cmap=plt.cm.Greys) # font size
plt.title("Confusion Matrix - IF Home C_real", fontsize=10, fontweight='bold')
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\LUM_IF_real_r.png', bbox_inches='tight')

# Original confusion matrix
array = [[8463, 297],
         [7822, 938]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]


plt.rcParams.update({'font.size': 10})
# df_cm = pd.DataFrame(array, range(2), range(2))

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])
# LABELS = ['Benign', 'DoS']
# LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Greys) # font size
plt.title("Confusion Matrix - IF Home B_real", fontsize=10, fontweight='bold')
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\LUM_IF_real_n.png', bbox_inches='tight')

# %% [markdown]
# ### 1D-CONV-AE - Home B

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original confusion matrix
array = [[8719, 41],
         [8624, 136]]

plt.rcParams.update({'font.size': 10})
df_cm = pd.DataFrame(array, range(2), range(2))
# LABELS = ['Benign', 'DoS']
LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Greys) # font size
plt.title("Confusion Matrix - 1D-CONV-AE Home B_real", fontsize=10, fontweight='bold')
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\LUM_1D-CONV-AE_real_r.png', bbox_inches='tight')

# Original confusion matrix
array = [[8719, 41],
         [8624, 136]]

# Normalize the confusion matrix
conf_matrix = np.array(array).astype('float')
conf_matrix = conf_matrix / conf_matrix.sum(axis=1)[:, np.newaxis]


plt.rcParams.update({'font.size': 10})
# df_cm = pd.DataFrame(array, range(2), range(2))

# Create a DataFrame for Seaborn heatmap
df_cm = pd.DataFrame(conf_matrix, index=['Benign', 'Attack'], columns=['Benign', 'Attack'])
# LABELS = ['Benign', 'DoS']
# LABELS = ['Benign', 'Attack']
plt.figure(figsize=(4, 3))
sns.heatmap(df_cm, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="0.2f",annot_kws={"size": 10}, 
           linewidths=0.5, square=True, cbar_kws={'label': 'Home B_real'}, cmap=plt.cm.Greys) # font size
plt.title("Confusion Matrix - 1D-CONV-AE Home B_real", fontsize=10, fontweight='bold')
plt.ylabel('True class',fontsize=10, fontweight='bold')
plt.xlabel('Predicted class',fontsize=10, fontweight='bold')
plt.savefig(r'C:\Users\olufe\projects\Journal\Diagrams\Home_B_up\LUM_1D-CONV-AE_real_n.png', bbox_inches='tight')
