# %%
import pandas as pd

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_real_test.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Print the counts
print("Class Counts:")
print(class_counts)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25504\2273367270.py in <module>
#       3 # Load the CSV file
#       4 csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_real_test.csv"
# ----> 5 df = pd.read_csv(csv_path)
#       6
#       7 # Count the occurrences of each class
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_synthetic_train.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the class counts
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class Counts')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_synthetic_train.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home A_Synthetic Train')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_B_synthetic_train.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home B_Synthetic Train')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_C_synthetic_train.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home C_Synthetic Train')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_unsupervise_train.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home A_B_C_unsupervised Train')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home A_Sim Test')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_B_sim_test.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home B_Sim Test')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_C_sim_test.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home C_Sim Test')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_real_test.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home A_real Test')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_B_real_test.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home B_real Test')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_C_real_test.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home C_real Test')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
csv_path = "C:\Project\Journal\dataset\home_A_synthetic_sim_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home A_Train_Sim_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
csv_path = "C:\Project\Journal\dataset\home_B_synthetic_sim_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home B_Train_Sim_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
csv_path = "C:\Project\Journal\dataset\home_C_synthetic_sim_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home C_Train_Sim_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\Project\Journal\dataset\HomeA_unsupervised_sim_combined_shuffled.csv"
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\HomeA_unsupervised_sim_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home A_uns_train_Sim_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
#csv_path = "C:\Project\Journal\dataset\home_B_synthetic_sim_combined_shuffled.csv"
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\HomeB_unsupervise_sim_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home B_uns_train_Sim_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
#csv_path = "C:\Project\Journal\dataset\home_B_synthetic_sim_combined_shuffled.csv"
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\HomeC_unsupervise_sim_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home C_uns_train_Sim_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
#csv_path = "C:\Project\Journal\dataset\home_B_synthetic_sim_combined_shuffled.csv"
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\HomeA_unsupervised_real_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home A_uns_train_real_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
#csv_path = "C:\Project\Journal\dataset\home_B_synthetic_sim_combined_shuffled.csv"
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\HomeB_unsupervise_real_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home B_uns_train_real_test ')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
#csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\psa_journal_home_A_sim_test.csv"
#csv_path = "C:\Project\Journal\dataset\home_B_synthetic_sim_combined_shuffled.csv"
csv_path = "C:\\Users\\olufe\\projects\\Journal\\dataset\\HomeC_unsupervise_real_combined_shuffled.csv"
df = pd.read_csv(csv_path)

# Count the occurrences of each class
class_counts = df['Label'].value_counts()

# Visualize the counts
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['blue', 'red'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Class Counts - Home C_uns_train_real_test ')
plt.xticks(rotation=0)
plt.show()
