# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A (AUC values)
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']
auc_values = [
    [98.76, 96.47, 96.56],
    [98.91, 97.02, 96.68],
    [98.78, 97.56, 97.24],
    [98.78, 97.64, 97.95],
    [98.53, 96.25, 95.37],
    [98.53, 96.54, 96.49]
]

# Flatten AUC values
flat_auc_values = [auc_values[i][j] for i in range(len(auc_values)) for j in range(len(models))]

# Create a bar chart
fig, ax = plt.subplots(figsize=(10, 6))
width = 0.2
x = np.arange(len(models))

for i, dataset in enumerate(datasets):
    model_auc = flat_auc_values[i * len(models):(i + 1) * len(models)]
    ax.bar(
        x + width * i,
        model_auc,
        width=width,
        label=f'Dataset {dataset}',
    )

ax.set_xlabel('Models')
ax.set_ylabel('AUC (%)')
ax.set_title('AUC Comparison for Different Models and Datasets')
ax.set_xticks(x + width * (len(datasets) - 1) / 2)
ax.set_xticklabels(models)
ax.legend(datasets, title='Datasets')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('C:\\Users\\olufe\\projects\\Journal\\Diagrams\\Home_A\\AUC-score_models.png',bbox_inches='tight')
plt.show()

# %%
# Flatten AUC values for the histogram
flat_auc_values = [auc for sublist in auc_values for auc in sublist]

# Create a histogram
plt.figure(figsize=(10, 6))
plt.hist(flat_auc_values, bins=10, edgecolor='k', alpha=0.7)
plt.xlabel('AUC (%)')
plt.ylabel('Frequency')
plt.title('Distribution of AUC Values')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A (F1-score values)
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']
f1_score_values = [
    [0.9492, 0.9113, 0.9723],
    [0.9530, 0.9146, 0.9212],
    [0.9590, 0.9296, 0.9486],
    [0.9599, 0.9259, 0.9413],
    [0.9480, 0.9168, 0.9168],
    [0.9540, 0.9216, 0.9251]
]

# Flatten F1-score values
flat_f1_score_values = [f1_score_values[i][j] for i in range(len(f1_score_values)) for j in range(len(models))]

# Create a bar chart for F1-score
fig, ax = plt.subplots(figsize=(10, 6))
width = 0.2
x = np.arange(len(models))

for i, dataset in enumerate(datasets):
    model_f1_score = flat_f1_score_values[i * len(models):(i + 1) * len(models)]
    ax.bar(
        x + width * i,
        model_f1_score,
        width=width,
        label=f'Dataset {dataset}',
    )

ax.set_xlabel('Models')
ax.set_ylabel('F1-score')
ax.set_title('F1-score Comparison for Different Models and Datasets')
ax.set_xticks(x + width * (len(datasets) - 1) / 2)
ax.set_xticklabels(models)
ax.legend(datasets, title='Datasets')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('C:\\Users\\olufe\\projects\\Journal\\Diagrams\\Home_A\\F1-score_models.png',bbox_inches='tight')
plt.show()

# Create a histogram for F1-score
plt.figure(figsize=(10, 6))
plt.hist(flat_f1_score_values, bins=10, edgecolor='k', alpha=0.7)
plt.xlabel('F1-score')
plt.ylabel('Frequency')
plt.title('Distribution of F1-score Values')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('C:\\Users\\olufe\\projects\\Journal\\Diagrams\\Home_A\\Distribution_F1-score_models.png',bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']

# Evaluation metrics data (AUC, F1-score, accuracy, precision, recall)
evaluation_metrics = ['AUC', 'F1-score', 'Accuracy', 'Precision', 'Recall']
metric_values = [
    [
        [98.76, 0.9492, 0.9521, 0.9839, 0.9169],
        [96.47, 0.9113, 0.9197, 0.9886, 0.8452],
        [96.56, 0.9723, 0.9733, 0.9816, 0.9633]
    ],
    [
        [98.91, 0.9530, 0.9555, 0.9875, 0.9209],
        [97.02, 0.9146, 0.9223, 0.9894, 0.8505],
        [96.68, 0.9212, 0.9243, 0.9383, 0.9048]
    ],
    [
        [98.78, 0.9590, 0.9615, 0.9921, 0.9281],
        [97.56, 0.9296, 0.9359, 0.9957, 0.8718],
        [97.24, 0.9486, 0.9514, 0.8718, 0.9237]
    ],
    [
        [98.78, 0.9599, 0.9624, 0.9927, 0.9293],
        [97.64, 0.9259, 0.9327, 0.9942, 0.8662],
        [97.95, 0.9413, 0.9441, 0.9583, 0.9250]
    ],
    [
        [98.53, 0.9480, 0.9526, 0.9837, 0.9116],
        [96.25, 0.9168, 0.9269, 0.9906, 0.8539],
        [95.37, 0.9168, 0.9168, 0.9406, 0.8791]
    ],
    [
        [98.53, 0.9540, 0.9570, 0.9894, 0.9209],
        [96.54, 0.9216, 0.9291, 0.9911, 0.8612],
        [96.49, 0.9251, 0.9293, 0.9487, 0.9026]
    ]
]

# Create a histogram for all metrics together in percentage
plt.figure(figsize=(12, 6))

for metric in evaluation_metrics:
    if metric != 'F1-score':  # Multiply by 100 for metrics other than F1-score
        flat_metric_values = [
            metric_values[i][j][k] * 100 for i in range(len(metric_values))
            for j in range(len(models))
            for k in range(len(datasets))
        ]
    else:
        flat_metric_values = [
            metric_values[i][j][k] for i in range(len(metric_values))
            for j in range(len(models))
            for k in range(len(datasets))
        ]

    plt.hist(
        flat_metric_values,
        bins=10,
        alpha=0.6,
        label=metric,
    )

plt.xlabel('Metric Values')
plt.ylabel('Frequency')
plt.title('Distribution of Evaluation Metrics for All Models and Datasets (in %)')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']

# Precision data
precision_values = [
    [
        [0.9839, 0.9886, 0.9816],
        [0.9875, 0.9894, 0.9383],
        [0.9837, 0.9906, 0.9406]
    ],
    [
        [0.9839, 0.9886, 0.9816],
        [0.9875, 0.9894, 0.9383],
        [0.9837, 0.9906, 0.9406]
    ],
    [
        [0.9839, 0.9886, 0.9816],
        [0.9875, 0.9894, 0.9383],
        [0.9837, 0.9906, 0.9406]
    ],
    [
        [0.9839, 0.9886, 0.9816],
        [0.9875, 0.9894, 0.9383],
        [0.9837, 0.9906, 0.9406]
    ],
    [
        [0.9839, 0.9886, 0.9816],
        [0.9875, 0.9894, 0.9383],
        [0.9837, 0.9906, 0.9406]
    ],
    [
        [0.9839, 0.9886, 0.9816],
        [0.9875, 0.9894, 0.9383],
        [0.9837, 0.9906, 0.9406]
    ]
]

# Flatten precision values for all models and datasets
flat_precision_values = [
    precision_values[i][j][k] for i in range(len(precision_values))
    for j in range(len(models))
    for k in range(len(datasets))
]

# Create a histogram for Precision
plt.figure(figsize=(8, 6))

plt.hist(
    flat_precision_values,
    bins=10,
    alpha=0.6,
    color='blue',
)

plt.xlabel('Precision Values')
plt.ylabel('Frequency')
plt.title('Distribution of Precision Values for All Models and Datasets')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']

# Evaluation metrics data (AUC, F1-score, accuracy, precision, recall)
evaluation_metrics = ['AUC', 'F1-score', 'Accuracy', 'Precision', 'Recall']
metric_values = [
    [
        [98.76, 0.9492, 0.9521, 0.9839, 0.9169],
        [96.47, 0.9113, 0.9197, 0.9886, 0.8452],
        [96.56, 0.9723, 0.9733, 0.9816, 0.9633]
    ],
    [
        [98.91, 0.9530, 0.9555, 0.9875, 0.9209],
        [97.02, 0.9146, 0.9223, 0.9894, 0.8505],
        [96.68, 0.9212, 0.9243, 0.9383, 0.9048]
    ],
    [
        [98.78, 0.9590, 0.9615, 0.9921, 0.9281],
        [97.56, 0.9296, 0.9359, 0.9957, 0.8718],
        [97.24, 0.9486, 0.9514, 0.8718, 0.9237]
    ],
    [
        [98.78, 0.9599, 0.9624, 0.9927, 0.9293],
        [97.64, 0.9259, 0.9327, 0.9942, 0.8662],
        [97.95, 0.9413, 0.9441, 0.9583, 0.9250]
    ],
    [
        [98.53, 0.9480, 0.9526, 0.9837, 0.9116],
        [96.25, 0.9168, 0.9269, 0.9906, 0.8539],
        [95.37, 0.9168, 0.9168, 0.9406, 0.8791]
    ],
    [
        [98.53, 0.9540, 0.9570, 0.9894, 0.9209],
        [96.54, 0.9216, 0.9291, 0.9911, 0.8612],
        [96.49, 0.9251, 0.9293, 0.9487, 0.9026]
    ]
]

# Create a histogram for all metrics together with different colors
colors = ['b', 'g', 'r', 'c', 'm']

plt.figure(figsize=(12, 6))

for i, metric in enumerate(evaluation_metrics):
    flat_metric_values = [
        metric_values[j][k][i] for j in range(len(metric_values))
        for k in range(len(models))
    ]

    plt.hist(
        flat_metric_values,
        bins=10,
        alpha=0.6,
        label=metric,
        color=colors[i]
    )

plt.xlabel('Metric Values')
plt.ylabel('Frequency')
plt.title('Distribution of Evaluation Metrics for All Models and Datasets')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']

# Evaluation metrics data (AUC, F1-score, accuracy, precision, recall)
evaluation_metrics = ['AUC', 'F1-score', 'Accuracy', 'Precision', 'Recall']
metric_values = [
    [
        [98.76, 0.9492, 0.9521, 0.9839, 0.9169],
        [96.47, 0.9113, 0.9197, 0.9886, 0.8452],
        [96.56, 0.9723, 0.9733, 0.9816, 0.9633]
    ],
    [
        [98.91, 0.9530, 0.9555, 0.9875, 0.9209],
        [97.02, 0.9146, 0.9223, 0.9894, 0.8505],
        [96.68, 0.9212, 0.9243, 0.9383, 0.9048]
    ],
    [
        [98.78, 0.9590, 0.9615, 0.9921, 0.9281],
        [97.56, 0.9296, 0.9359, 0.9957, 0.8718],
        [97.24, 0.9486, 0.9514, 0.8718, 0.9237]
    ],
    [
        [98.78, 0.9599, 0.9624, 0.9927, 0.9293],
        [97.64, 0.9259, 0.9327, 0.9942, 0.8662],
        [97.95, 0.9413, 0.9441, 0.9583, 0.9250]
    ],
    [
        [98.53, 0.9480, 0.9526, 0.9837, 0.9116],
        [96.25, 0.9168, 0.9269, 0.9906, 0.8539],
        [95.37, 0.9168, 0.9168, 0.9406, 0.8791]
    ],
    [
        [98.53, 0.9540, 0.9570, 0.9894, 0.9209],
        [96.54, 0.9216, 0.9291, 0.9911, 0.8612],
        [96.49, 0.9251, 0.9293, 0.9487, 0.9026]
    ]
]

# Create a histogram for all metrics together with different colors
colors = ['b', 'g', 'r', 'c', 'm']

plt.figure(figsize=(12, 6))

for i, metric in enumerate(evaluation_metrics):
    flat_metric_values = [
        metric_values[j][k][i] for j in range(len(metric_values))
        for k in range(len(models))
    ]

    plt.hist(
        flat_metric_values,
        bins=10,
        alpha=0.6,
        label=metric,
        color=colors[i]
    )

plt.xlabel('Metric Values')
plt.ylabel('Frequency')
plt.title('Distribution of Evaluation Metrics for All Models and Datasets')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']

# Evaluation metrics data (AUC, F1-score, accuracy, precision, recall)
evaluation_metrics = ['AUC', 'F1-score', 'Accuracy', 'Precision', 'Recall']
metric_values = [
    [
        [98.76, 0.9492, 0.9521, 0.9839, 0.9169],
        [96.47, 0.9113, 0.9197, 0.9886, 0.8452],
        [96.56, 0.9723, 0.9733, 0.9816, 0.9633]
    ],
    [
        [98.91, 0.9530, 0.9555, 0.9875, 0.9209],
        [97.02, 0.9146, 0.9223, 0.9894, 0.8505],
        [96.68, 0.9212, 0.9243, 0.9383, 0.9048]
    ],
    [
        [98.78, 0.9590, 0.9615, 0.9921, 0.9281],
        [97.56, 0.9296, 0.9359, 0.9957, 0.8718],
        [97.24, 0.9486, 0.9514, 0.8718, 0.9237]
    ],
    [
        [98.78, 0.9599, 0.9624, 0.9927, 0.9293],
        [97.64, 0.9259, 0.9327, 0.9942, 0.8662],
        [97.95, 0.9413, 0.9441, 0.9583, 0.9250]
    ],
    [
        [98.53, 0.9480, 0.9526, 0.9837, 0.9116],
        [96.25, 0.9168, 0.9269, 0.9906, 0.8539],
        [95.37, 0.9168, 0.9168, 0.9406, 0.8791]
    ],
    [
        [98.53, 0.9540, 0.9570, 0.9894, 0.9209],
        [96.54, 0.9216, 0.9291, 0.9911, 0.8612],
        [96.49, 0.9251, 0.9293, 0.9487, 0.9026]
    ]
]

# Create a histogram for all metrics together with different colors
colors = ['b', 'g', 'r', 'c', 'm']
plt.figure(figsize=(12, 6))

for i, metric in enumerate(evaluation_metrics):
    flat_metric_values = [
        metric_values[j][k][i] for j in range(len(metric_values))
        for k in range(len(models))
    ]

    plt.hist(
        flat_metric_values,
        bins=10,
        alpha=0.6,
        label=metric,
        color=colors[i]
    )

plt.xlabel('Metric Values')
plt.ylabel('Frequency')
plt.title('Distribution of Evaluation Metrics for All Models and Datasets')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table A
models = ['XGB', 'RF', 'MLP']
datasets = ['Sim', 'Real']

# Evaluation metrics data (AUC, F1-score, accuracy, precision, recall)
evaluation_metrics = ['AUC', 'F1-score', 'Accuracy', 'Precision', 'Recall']
metric_values = [
    [
        [98.76, 0.9492, 0.9521, 0.9839, 0.9169],
        [96.47, 0.9113, 0.9197, 0.9886, 0.8452],
        [96.56, 0.9723, 0.9733, 0.9816, 0.9633]
    ],
    [
        [98.91, 0.9530, 0.9555, 0.9875, 0.9209],
        [97.02, 0.9146, 0.9223, 0.9894, 0.8505],
        [96.68, 0.9212, 0.9243, 0.9383, 0.9048]
    ],
    [
        [98.78, 0.9590, 0.9615, 0.9921, 0.9281],
        [97.56, 0.9296, 0.9359, 0.9957, 0.8718],
        [97.24, 0.9486, 0.9514, 0.8718, 0.9237]
    ],
    [
        [98.78, 0.9599, 0.9624, 0.9927, 0.9293],
        [97.64, 0.9259, 0.9327, 0.9942, 0.8662],
        [97.95, 0.9413, 0.9441, 0.9583, 0.9250]
    ],
    [
        [98.53, 0.9480, 0.9526, 0.9837, 0.9116],
        [96.25, 0.9168, 0.9269, 0.9906, 0.8539],
        [95.37, 0.9168, 0.9168, 0.9406, 0.8791]
    ],
    [
        [98.53, 0.9540, 0.9570, 0.9894, 0.9209],
        [96.54, 0.9216, 0.9291, 0.9911, 0.8612],
        [96.49, 0.9251, 0.9293, 0.9487, 0.9026]
    ]
]

# Create a histogram for all metrics together with different colors
colors = ['b', 'g', 'r', 'c', 'm']

plt.figure(figsize=(12, 6))

for i, metric in enumerate(evaluation_metrics):
    flat_metric_values = [
        metric_values[j][k][i] for j in range(len(metric_values))
        for k in range(len(models))
    ]

    plt.hist(
        flat_metric_values,
        bins=10,
        alpha=0.6,
        label=metric,
        color=colors[i]
    )

plt.xlabel('Metric Values')
plt.ylabel('Frequency')
plt.title('Distribution of Evaluation Metrics for All Models and Datasets')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# AUC scores for different models and datasets
auc_scores = [
    [98.76, 96.47, 96.56, 74.61, 67.31, 63.55, 98.91, 97.02, 96.68, 58.96, 61.12, 53.66],
    [98.78, 97.56, 97.24, 78.90, 77.04, 61.64, 98.78, 97.64, 97.95, 60.61, 71.77, 55.01],
    [98.53, 96.25, 95.37, 75.04, 64.95, 67.66, 98.53, 96.54, 96.49, 65.64, 54.95, 74.35]
]

# Flatten the list of AUC scores
flat_auc_scores = [score for sublist in auc_scores for score in sublist]

# Create a histogram for AUC scores
plt.hist(flat_auc_scores, bins=10, alpha=0.6, color='b')
plt.xlabel('AUC Score')
plt.ylabel('Frequency')
plt.title('Distribution of AUC Scores for All Models and Datasets')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Table
models = ['SYN-XGB', 'SYN-RF', 'SYN-MLP', 'UN-MLP-AE', 'UN-1D-CONV-AE', 'UN-IF']
datasets = ['Sim', 'Real']

# AUC scores for each model and dataset
auc_scores = [
    [98.76, 96.47, 96.56, 74.61, 67.31, 63.55],
    [98.91, 97.02, 96.68, 58.96, 61.12, 53.66],
    [98.78, 97.56, 97.24, 78.90, 77.04, 61.64],
    [98.78, 97.64, 97.95, 60.61, 71.77, 55.01],
    [98.53, 96.25, 95.37, 75.04, 64.95, 67.66],
    [98.53, 96.54, 96.49, 65.64, 54.95, 74.35]
]

# Create a histogram for AUC scores with different colors for each model
colors = ['b', 'g', 'r', 'c', 'm', 'y']
plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    auc_values = [auc_scores[j][i] for j in range(len(auc_scores))]
    plt.hist(
        auc_values,
        bins=10,
        alpha=0.6,
        label=model,
        color=colors[i]
    )

plt.xlabel('AUC Scores')
plt.ylabel('Frequency')
plt.title('Distribution of AUC Scores for Different Models and Datasets')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
